# %%
import numpy as np 
import pandas as pd 
import os

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_excel(r"C:\Users\rajan\Downloads\Data Visualization Assignment - Copy.xlsx")

# %%
print(df)
# Out:
#     Campaign ID                             Campaign Name  \
# 0    Campaign 1          SHU_6 (Educators and Principals)
# 1    Campaign 2  SHU3_ (Students Apart from India and US)
# 2    Campaign 3                   SHU_Students(Australia)
# 3    Campaign 4                     SHU_Students (Canada)
# 4    Campaign 5                       SHU_Students(Ghana)
# 5    Campaign 6                      SHU_Students (India)
# 6    Campaign 7                       SHU_Students(Nepal)
# 7    Campaign 8                    SHU_Students (Nigeria)
# 8    Campaign 9                         SHU_Students(UAE)
# 9   Campaign 10                          SHU_Students(UK)
# 10  Campaign 11                        SHU_Students (USA)
#
#                     Audience  \
# 0   Educators and Principals
# 1                   Students
# 2                   Students
# 3                   Students
# 4                   Students
# 5                   Students
# 6                   Students
# ...

# %%
df.head()
# Out:
#   Campaign ID                             Campaign Name  \
# 0  Campaign 1          SHU_6 (Educators and Principals)
# 1  Campaign 2  SHU3_ (Students Apart from India and US)
# 2  Campaign 3                   SHU_Students(Australia)
# 3  Campaign 4                     SHU_Students (Canada)
# 4  Campaign 5                       SHU_Students(Ghana)
#
#                    Audience  \
# 0  Educators and Principals
# 1                  Students
# 2                  Students
# 3                  Students
# 4                  Students
#
#                                            Geography  Reach  Impressions  \
# 0  Group 1      (Australia, Canada, United Kingdo...  23904        47139
# 1  Group 2        (Australia, Canada, United King...  46494        67313
# 2                                          Australia   3187         3572
# 3                                             Canada   3307         4267
# 4                                              Ghana  15024        20483
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.title(' Bar chart that shows how campaigns are performing')
df_new = df.rename(columns={'Cost per Result (CPR)': 'CPR',"Campaign ID":"Campaign_ID"})

sns.barplot(x='CPR',
            y="Campaign_ID", data=df_new,
            order=df_new.sort_values("CPR").Campaign_ID)
# Out:
# <AxesSubplot:title={'center':' Bar chart that shows how campaigns are performing'}, xlabel='CPR', ylabel='Campaign_ID'>

# %%
plt.figure(figsize=(8,6))
plt.title(' Bar chart that shows how campaigns are performing')
df_new = df.rename(columns={'Cost Per Click (CPC)': 'CPC',"Campaign ID":"Campaign_ID"})
sns.barplot(x='CPC',
            y="Campaign_ID", data=df_new,
            order=df_new.sort_values("CPC").Campaign_ID)
# Out:
# <AxesSubplot:title={'center':' Bar chart that shows how campaigns are performing'}, xlabel='CPC', ylabel='Campaign_ID'>

# %%
plt.figure(figsize=(8,6))
plt.title('Campaign Cost')
df_new = df.rename(columns={'Amount Spent in INR': 'Amount Spent',"Campaign ID":"Campaign_ID"})
sns.barplot(x='Amount Spent',
            y="Campaign_ID", data=df_new,
            order=df_new.sort_values("Amount Spent").Campaign_ID)
# Out:
# <AxesSubplot:title={'center':'Campaign Cost'}, xlabel='Amount Spent', ylabel='Campaign_ID'>

# %% [raw]
# From the above graph we infere that campaigns 5 and 3 have the lowest amount spent where as campaign 1 spent the highest.

# %%
plt.figure(figsize=(8,6))
plt.title('Reach of each campaign')
df_new = df.rename(columns={'Reach': 'Reach',"Campaign ID":"Campaign_ID"})
sns.barplot(x='Reach',
            y="Campaign_ID", data=df_new,
            order=df_new.sort_values("Reach").Campaign_ID)
# Out:
# <AxesSubplot:title={'center':'Reach of each campaign'}, xlabel='Reach', ylabel='Campaign_ID'>

# %%
plt.figure(figsize=(8,6))
plt.title('Impressions of each campaign')
df_new = df.rename(columns={'Impressions': 'Impressions',"Campaign ID":"Campaign_ID"})
sns.barplot(x='Impressions',
            y="Campaign_ID", data=df_new,
            order=df_new.sort_values("Impressions").Campaign_ID)
# Out:
# <AxesSubplot:title={'center':'Impressions of each campaign'}, xlabel='Impressions', ylabel='Campaign_ID'>

# %% [raw]
# 11,3,10 and 4 have low reaches and impressions

# %%
plt.figure(figsize=(8,6))
plt.title('Amount spent for every campaign location')
df_new = df.rename(columns={'Amount Spent in INR': 'Amount Spent',"Geography":"Geography"})
sns.barplot(x='Amount Spent',
            y="Geography", data=df_new,
            order=df_new.sort_values("Amount Spent").Geography)
# Out:
# <AxesSubplot:title={'center':'Amount spent for every campaign location'}, xlabel='Amount Spent', ylabel='Geography'>

# %%
df2= pd.read_excel(r"C:\Users\rajan\Downloads\Data Visualization Assignment - Age.xlsx")

# %%
plt.figure(figsize=(8,6))
plt.title('Individual campaigns reach every age group')
df2_new = df2.rename(columns={'Reach': 'Reach',"Age":"Age"})
sns.barplot(x='Reach',
            y="Age", data=df2_new,
            order=df2_new.sort_values("Reach").Age)
# Out:
# <AxesSubplot:title={'center':'Individual campaigns reach every age group'}, xlabel='Reach', ylabel='Age'>

# %% [raw]
# Comparing these results, it can be seen that campaign 3 and 11 have the lowest performance and can be considered for removal. While campaigns 4 and 10 are not ideal as well.
